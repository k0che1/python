# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statistics import mode
import warnings; warnings.simplefilter('ignore')

url = 'https://www.random.org/integers/?num=200&min=0&max=12&col=1&base=10&format=plain&rnd=new'
r = requests.get(url)
text = list(r.text)
a=[int(text[i]) for i in range(len(text)) if text[i]!='\n']

plt.figure(figsize=(8,5))
plt.hist(a, bins=np.arange(1,12))
plt.axvline(np.mean(a), color='r',label ='Выборочное среднее')
plt.axvline(np.mean(a)+np.std(a), color='g',label ='1σ')
plt.axvline(np.mean(a)-np.std(a), color='g',label ='-1σ')
plt.axvline(np.mean(a)+2*np.std(a), color='y',label ='2σ')
plt.axvline(np.mean(a)-2*np.std(a), color='y',label ='-2σ')
plt.axvline(mode(a), color='m',label ='Мода',linestyle='--')
plt.legend(bbox_to_anchor=(1.05, 0.5), loc='center left')
plt.show()

# %% [markdown]
# Глядя на гистограмму, можно сказать, что мода данного распределения равна 1.
